# %%
DATA_PATH = 'data'

# %%
import pandas as pd
from pathlib import Path

DATA_PATH = 'data'

file_name = 'Ozon_Crawler_Latest_info2025-04-07-12-57-51.xlsx'
df = pd.read_excel(Path(DATA_PATH) / file_name)
df.head(1)
# Out:
#     Sku (Sku)                                  Фото (CoverImage)  \
# 0  1871769771  https://cdn1.ozone.ru/s3/multimedia-1-b/732378...
#
#                        Название товара (ProductName) Продавец (SellerName)  \
# 0  Карты МИРА и РОССИИ настенные политические,160...            ИНТЕРТРЕЙД
#
#   Бренд (BrandName) Название категории (CategoryName)  \
# 0       Атлас Принт                        Карты мира
#
#    Цена соинвест (DiscountPrice)  Цена по карте (OzonCardPrice)  \
# 0                         1785.0                           1649
#
#    Сток FBO (StockFbm)  Сток FBS (StockFbs)  Ошибка загрузки (CrawlerError)  \
# 0                    0                   34                               0
#
#   Валюта (Currency)  Цена до скидки (BasePrice)  Рейтинг товара (AvgRating)  \
# 0               RUB                      3867.0                         5.0
#
#    Количество отзывов (Reviews)  \
# 0                             1
#
#                               Описание (Description)  \
# 0  Представляем вашему вниманию уникальный набор ...
#
#    Rich-контент (RichContent)  \
# 0                         NaN
#
#                                   Ссылка на карточку  \
# 0  https://www.ozon.ru/product/karty-mira-i-rossi...
#
#    SellerProductId (SellerProductId)
# 0                          191942573

# %%
import pandas as pd
from pathlib import Path

file_path = Path(DATA_PATH) / 'Карты_мира_озон.xlsm'
source_df = pd.read_excel(file_path)
source_df.head(1)
# Out:
#          SKU                                               Name  \
# 0  936454663  Карта мира географическая политическая интерак...
#
#                                             Category Схема Brand  \
# 0  Канцелярские товары/Бумажная продукция/Карты мира   FBO   NaN
#
#                                                Niche  Seller  Balance  \
# 0  Дом и сад/Декор и интерьер/Картины и панно/Гра...  GooDaY      346
#
#    Balance FBS  Warehouses count  ...  FBS  Base price  Category Position  \
# 0            0                12  ...    0        4990                  1
#
#    Categories Last Count  Sales Per Day Average  Turnover  Frozen stocks  \
# 0                      1                    5.2     66.54            112
#
#    Frozen stocks cost  Frozen stocks percent  is_primary
# 0              202832                  32.37       False
#
# [1 rows x 43 columns]

# %%
# # Collect images

# import nest_asyncio
# nest_asyncio.apply()

# from utils import parallel_download_img

# # Dataset name
# DATASET_NAME = "images_OZ_geo_5500"

# # Download image files using the 'Thumb' column for both URL and ID extraction
# results = await parallel_download_img(
#     df=source_df,
#     url_col='Thumb',
#     img_id_regex=r'/(\d+)\.jpg$',  # capture numeric ID before '.jpg'
#     dataset_name=DATASET_NAME,
#     base_download_dir=DATA_PATH,
#     max_concurrency=100,
#     delay=1.0
# )

# # Merge the list of results into your DataFrame as a new column
# Out:
# Downloading images: 100%|██████████| 5703/5703 [01:18<00:00, 72.57it/s]

# %%
# Save image

# source_df['image_name'] = results
# source_df.to_csv(Path(DATA_PATH) / 'OZ_geo_5500_no_descriptions.csv', index=None)
